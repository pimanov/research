# %%
import tools
import pipeSym_func as sym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pipeSym_func as sys
import math

# %%
def deform2_nnn(vel):
    u,v,w = vel
    
    ur_nnf = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                ur_nnf[k,j,i] = (u[k,j+1,i] - u[k,j,i]) / sym.wr.dimr.rt1[j] 
    
    ur_nnn = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                ur_nnn[k,j,i] = (ur_nnf[k+1,j,i] + ur_nnf[k,j,i])/2
    
    wx_nfn = sys.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                wx_nfn[k,j,i] = (w[k,j,i+1] - w[k,j,i]) / sym.wr.dimx.hx
    
    wx_nnn = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                wx_nnn[k,j,i] = (wx_nfn[k,j+1,i] + wx_nfn[k,j,i])/2
                
    return - ur_nnn * wx_nnn

# %%
def deform3_nnn(vel):
    u,v,w = vel
    
    ut_nfn = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                ut_nfn[k,j,i] = (u[k+1,j,i] - u[k,j,i]) / (sym.wr.dimr.yt[j-1] * sym.wr.dimt.ht)
    
    ut_nnn = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                ut_nnn[k,j,i] = (ut_nfn[k,j+1,i] + ut_nfn[k,j,i])/2
               
    vx_nnf = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                vx_nnf[k,j,i] = (v[k,j,i+1] - v[k,j,i]) / sym.wr.dimx.hx
                
    vx_nnn = sym.new_z_pfield()
    for k in range(1,Km+1):
        for j in range(1,Jm+1):
            for i in range(1,Im+1):
                vx_nnn[k,j,i] = (vx_nnf[k+1,j,i] + vx_nnf[k,j,i])/2
                
    return ut_nnn * vx_nnn

# %%
t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, vel2 = tools.get_scp("../orig-edge/Re2200-mean2.scp")

# %%
print t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, vel2.max()
# Out:
# 59.6124554189 0.298062277094 0.688934885581 2200.0 120.0 0.25 10 40 5 2 0.999766154013

# %%
t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, vel = tools.get_scp("../orig-edge/Re2200-mean.scp")

# %%
print t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, vel.max()
# Out:
# 59.6124554189 0.298062277094 0.688934885581 2200.0 120.0 0.25 10 40 5 2 0.99988307017

# %%
sym.init(Xmax, epsr, nsym, lx, Jm, lt, Re=Re)

# %%
sym.look()
# Out:
# Xmax=120.000000, epsr=0.250000, nsym=2
# Im=1024, Jm=40, Km=32
# hx=0.117188, ht=0.049087, real_nsym=2.000000
# Re=2200.000000

# %%
x = np.linspace(0,Xmax,2**lx, endpoint=False)

# %%
puls = vel2 - vel**2

# %%
upuslx = tools.cs_mean(puls[0], Jm, epsr, lt, nsym)**0.5
vpuslx = tools.cs_mean(puls[1], Jm, epsr, lt, nsym)**0.5
wpuslx = tools.cs_mean(puls[2], Jm, epsr, lt, nsym)**0.5

# %%
plt.plot(x, upuslx[1:-1])
plt.plot(x, vpuslx[1:-1])
plt.plot(x, wpuslx[1:-1])

# %%
ustrx = tools.cs_mean((vel[0] - vel[0,1:-1].mean(0))**2, Jm, epsr, lt, nsym)**0.5
vstrx = tools.cs_mean((vel[1] - vel[1,1:-1].mean(0))**2, Jm, epsr, lt, nsym)**0.5
wstrx = tools.cs_mean((vel[2] - vel[2,1:-1].mean(0))**2, Jm, epsr, lt, nsym)**0.5

# %%
plt.plot(x, ustrx[1:-1])
plt.plot(x, vstrx[1:-1])
plt.plot(x, wstrx[1:-1])

# %%
t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, om = tools.get_scp("Re2200_om_mean.scp")

# %%
print t, dt, cf, Re, Xmax, epsr, lx, Jm, lt, nsym, om.max()
# Out:
# 59.6124554189 0.298062277094 0.688934885581 2200.0 120.0 0.25 10 40 5 2 3.48833853947

# %%
oxx = tools.cs_mean(om[0]**2, Jm, epsr, lt, nsym)**0.5

# %%
plt.plot(x, oxx[1:-1])

# %%
Im = sym.wr.dimx.Im
Jm = sym.wr.dimr.Jm
Km = sym.wr.dimt.Km

# %%
vel[:,:,:,0] = vel[:,:,:,-2]
vel[:,:,:,-1] = vel[:,:,:,1]

# %%
vel[0:2,0,:,:] = vel[0:2,1,:,:]
vel[0:2,-1,:,:] = vel[0:2,-2,:,:]

vel[2,0,:,:] = 0.0
vel[2,-2,:,:] = 0.0

# %%
dmm = sym.new_z_vfield()

# %%
dmm[1] = deform2_nnn(vel)
dmm[2] = deform3_nnn(vel)

# %%
dmm[:,2:-2,2:-2,2:-2].max()
# Out:
# 0.012700596109179561

# %%
t, dt, Dp, Re, Xmax, epsr, lx, Jm, lt, nsym, dcc = tools.get_scp("part_deform_mean.scp")

# %%
print t, dt, Dp, Re, Xmax, epsr, lx, Jm, lt, nsym, dcc.max()
# Out:
# 0.0 0.1 0.0 2200.0 120.0 0.25 10 40 5 2 0.0138398632397

# %%
d = dcc - dmm

# %%
d.max()
# Out:
# 0.012579308063951937

# %%
d2x = tools.cs_mean(d[1]**2, Jm, epsr, lt, nsym)**0.5
d3x = tools.cs_mean(d[2]**2, Jm, epsr, lt, nsym)**0.5
Dx = tools.cs_mean((d[1]+d[2])**2, Jm, epsr, lt, nsym)**0.5

# %%
plt.plot(x, d2x[1:-1])
plt.plot(x, d3x[1:-1])
#plt.plot(x, (d1x+d2x)[1:-1])

plt.plot(x, Dx[1:-1])

# %%
hx = sym.wr.dimx.hx

# %%
10.0/hx
# Out:
# 85.333333333333329

# %%
nii = 10
ii = [int(795 + i/hx) for i in range(nii)]

# %%
ii
# Out:
# [795, 803, 812, 820, 829, 837, 846, 854, 863, 871]

# %%
plt.figure(figsize=(8,8))

plt.subplot(2,1,1)
plt.title("pulsations d", fontsize=16)
plt.plot(x, Dx[1:-1], "c", lw=2, label="d2+d3")
plt.plot(x, d2x[1:-1], "r", label="d2")
plt.plot(x, d3x[1:-1], "b", label="d3")
plt.plot(x, 0.06*oxx[1:-1], 'k--', label="0.06*ox")
#plt.plot(x, 0.025*upuslx[1:-1], 'k--', label="0.025*puls")
plt.xlim(60,110)
plt.legend(loc=2)

for i in ii:
    plt.plot([x[i-1], x[i-1]], [0.0, 0.0005],  "k")

plt.subplot(2,1,2)
plt.plot(x, ustrx[1:-1], "r", label="streaks")
plt.plot(x, upuslx[1:-1], label="pulsations")
plt.plot(x, oxx[1:-1], "k", label="ox")
plt.xlim(60,110)
plt.legend(loc=2)

# %% [markdown]
# ## Add

# %%
dcc_sum = dcc[1] + dcc[2]
dmm_sum = dmm[1] + dmm[2]
d11_sum = d[1] + d[2]

# %%
dccx = tools.cs_mean(dcc_sum**2, Jm, epsr, lt, nsym)**0.5
dmmx = tools.cs_mean(dmm_sum**2, Jm, epsr, lt, nsym)**0.5
d11x = tools.cs_mean(d11_sum**2, Jm, epsr, lt, nsym)**0.5

# %%
plt.figure(figsize=(8,4))

plt.title("decomposition of d", fontsize=16)
plt.plot(x, dccx[1:-1], "g", lw=2, label="d(V+v')")
plt.plot(x, dmmx[1:-1], "r", label="d(V)")
plt.plot(x, d11x[1:-1], "b", label="d(v')")
plt.plot(x, 0.06*oxx[1:-1], 'k--', label="0.06*ox")
#plt.plot(x, 0.025*upuslx[1:-1], 'k--', label="0.025*puls")
plt.xlim(60,110)
plt.legend(loc=2)

for i in ii:
    plt.plot([x[i-1], x[i-1]], [0.0, 0.0005],  "k")

# %%
(om[0]*d[1]).max()
# Out:
# 0.00056196006916521166

# %%
od2x = tools.cs_mean(om[0]*d[1], Jm, epsr, lt, nsym)
od3x = tools.cs_mean(om[0]*d[2], Jm, epsr, lt, nsym)
oDx = tools.cs_mean(om[0]*(d[1]+d[2]), Jm, epsr, lt, nsym)

# %%
plt.plot(x, od2x[1:-1])
plt.plot(x, od3x[1:-1])
plt.plot(x, oDx[1:-1])

# %%
plt.figure(figsize=(8,7))

plt.title("pulsations om*d", fontsize=16)
plt.plot(x, oDx[1:-1], "c", lw=2, label="ox(d2+d3)")
plt.plot(x, od2x[1:-1], "r", label="ox d2")
plt.plot(x, od3x[1:-1], "b", label="ox d3")
plt.plot(x, 0.002*oxx[1:-1], 'k--', label="0.002*ox")
plt.xlim(60,110)
plt.legend(loc=2)

for i in ii:
    plt.plot([x[i-1], x[i-1]], [-0.000015, 0.000015],  "k")

# %% [markdown]
# ## Add

# %%
odccx = tools.cs_mean(om[0]*dcc_sum, Jm, epsr, lt, nsym)
odmmx = tools.cs_mean(om[0]*dmm_sum, Jm, epsr, lt, nsym)
od11x = tools.cs_mean(om[0]*d11_sum, Jm, epsr, lt, nsym)

# %%
plt.figure(figsize=(8,7))

plt.title("decomposition of om*d", fontsize=16)
plt.plot(x, odccx[1:-1], "g", lw=2, label="ox*d(V+v')")
plt.plot(x, odmmx[1:-1], "r", label="ox*d(V)")
plt.plot(x, od11x[1:-1], "b", label="ox*d(v')")
plt.plot(x, 0.002*oxx[1:-1], 'k--', label="0.002*ox")
plt.xlim(60,110)
plt.legend(loc=2)

for i in ii:
    plt.plot([x[i-1], x[i-1]], [-0.000015, 0.000015],  "k")

# %%
cf
# Out:
# 0.6889348855813127

# %%
import matplotlib.ticker
import math
import matplotlib.tri as tri
from matplotlib.ticker import MaxNLocator

def polar_plot(u, u1, amp):
    (umin, umax) =amp
    
    Im = sym.wr.dimx.Im
    Jm = sym.wr.dimr.Jm
    Km = sym.wr.dimt.Km
    
    radius = sym.wr.dimr.yt[1:Jm+1]
    angles = np.linspace(0, math.pi/2, Km, endpoint = False) + sym.wr.dimt.ht/2
    angles = np.repeat( angles[ ..., np.newaxis ], Jm, axis = 1 )

    x = (radius * np.cos( angles )).flatten()
    y = (radius * np.sin( angles )).flatten()
    triang = tri.Triangulation(x, y)

    z = u[1:-1,1:-1].flatten()
    z1 = u1[1:-1,1:-1].flatten() - cf
    
    level0 = MaxNLocator(nbins=1).tick_values(-1, 1)
    levels = MaxNLocator(nbins=16).tick_values(umin, umax)
    scmap = plt.get_cmap()

    plt.gca().set_aspect('equal')
    plt.tricontourf( triang, z, levels = levels, cmap = scmap)
    plt.tricontour ( triang, z1, colors = 'k', levels = level0)
    plt.xlim(0, 1.0)
    plt.ylim(0, 1.0)

    ax = plt.gca()
    ax.xaxis.set_major_locator(plt.NullLocator())
    ax.yaxis.set_major_locator(plt.NullLocator())
    #ax.spines['top'].set_visible(False)
    #ax.spines['bottom'].set_visible(False)
    #ax.spines['right'].set_visible(False)
    #ax.spines['left'].set_visible(False)
    return

# %%
plt.figure(figsize=(12,20))

damp = max(d[1, 1:-1,1:-1,1:-1].max(), d[2,1:-1,1:-1,1:-1].max(), (d[1]+d[2])[1:-1,1:-1,1:-1].max())
omax = om[0,1:-1,1:-1,1:-1].max()
pmax = puls[0,1:-1,1:-1,1:-1].max()

n=1
for u,amp in ((d[1], (-damp, damp)), (d[2], (-damp, damp)), (d[1]+d[2], (-damp, damp)), 
              (om[0], (-omax, omax)), (puls[0], (-pmax, pmax)), (vel[0], (0,1))):
    m = n
    for i in ii:
        plt.subplot(nii,6,m)
        
        if m <= 6:
            plt.title({1:"d2", 2:"d3", 3:"d2+d3", 4:"ox", 5:"puls", 6:"u"}[m], fontsize=14)
        
        if m > (nii - 1) * 6:
            plt.xlabel({1:"d2", 2:"d3", 3:"d2+d3", 4:"ox", 5:"puls", 6:"u"}[m - (nii - 1) * 6], fontsize=14)
        
        if n == 1:
            plt.ylabel("x=%5.1f" % round(x[i]), fontsize=14)
         
        polar_plot(u[:,:,i], vel[0,:,:,i], amp)
        
        m += 6
        
    n += 1

# %% [markdown]
# Област действия пульсаций и среднего течения достаточно четко разделяются.

# %% [markdown]
# ## Combo part

# %%
streax = vel[0] - vel[0,1:-1].mean(0)

# %%
plt.figure(figsize=(14,23.5))

damp = max(dcc_sum[1:-1,1:-1,1:-1].max(), dmm_sum[1:-1,1:-1,1:-1].max(), d11_sum[1:-1,1:-1,1:-1].max())
omax = om[0,1:-1,1:-1,1:-1].max()
pmax = puls[0,1:-1,1:-1,1:-1].max()
smax = streax[1:-1,1:-1,1:-1].max()

n=1
for u,amp in ((vel[0], (0,1)), (om[0], (-omax, omax)), (dcc_sum, (-damp, damp)), 
              (dmm_sum, (-damp, damp)), (d11_sum, (-damp, damp)), (puls[0], (-pmax, pmax))):
    m = n
    for i in ii:
        plt.subplot(nii,6,m)
        
        if m <= 6:
            plt.title({1:"u", 2:"ox", 3:"d(V+v1)", 4:"d(V)", 5:"d(v1)", 6:"puls"}[m], fontsize=14)
        
        if m > (nii - 1) * 6:
            plt.xlabel({1:"u", 2:"ox", 3:"d(V+v1)", 4:"d(V)", 5:"d(v1)", 6:"puls"}[m - (nii - 1) * 6], fontsize=14)
        
        if n == 1:
            plt.ylabel("x=%5.1f" % round(x[i]), fontsize=14)
            
        polar_plot(u[:,:,i], vel[0,:,:,i], amp)
        
        m += 6
        
    n += 1
