# %% [markdown]
# # Поиск новых периодических решений на верхней ветки. Часть 3.

# %% [markdown]
# С последнего раза мне удалось продвинуться вперед по Re при nsym = 2. Пройти от Re=1890 до Re=2350. На графике ниже эти решения выделены синими, также, как и найденные ранее решения с nsym=2. Таким образом, у нас теперь есть локализованное решение на верхней ветке с Re=2200. Можно продолжать двигаться по Re дальше, никаких новых препятствий я не встретил.
#
# Нужно отметить, что пройти прямо вверху по Рейнольдсу при Re=1890, nsym=2 я так и не смог. Я обошел это место при nsym=2.06, затем при Re=1950 спустился снова к nsym=2, и смог продлить решение как вперед, так и назад, но пройти тучку Re=1890, nsym=2 мне не удалось даже в обратном направлении. На этом месте видно излом, на картинке T(Re) и cf(Re). На графике nsym(Re) синяя прямая как будто сплошная, концы приблизились друг от другу очень близко, так что разрыва на ней даже не видно, но он есть.

# %% [markdown]
# <img src="solutions3.png">

# %% [markdown]
# Затем я снова попробовал увеличить nsym до 3 уже при Re=1950 и при Re=2100 (красные вертикальные штрихи при соответствующих числах Рейнольдса). В первом случае я снова не смог продвинуться дальше nsym=2.1 примерно. Во втором случае я вышел на разворот немного не достигнув nsym=2.1. На следующем графике представлен этот разворот. Красная черточка - последний шаг, который я сделал к настоящему моменту. Соответственно первый на другом конце этой кривой, при nsym=2.

# %% [markdown]
# <img src="nsym_turn.png">

# %% [markdown]
# Решение с nsym=3 в данном случае не существует, но зато можно найти новое решение при nsym=2. Можно также попробовать продлить решения в сторону уменьшения nsym, возможно там тоже будет разворот, и тогда можно будет найти еще новое решение при nsym=2, а может и добраться до nsym=3.
#
# При других числах Рейнольдса такой разворот тоже наверняка существует, но возможно он происходит при nsym>3, и тогда можно найти решение с nsym=3. На графике ниже показана зависимость cf и T от nsym при других Re, при которых я считал. В общем-то общего мало чего можно найти.

# %% [markdown]
# <img src="nsym_all.png">
